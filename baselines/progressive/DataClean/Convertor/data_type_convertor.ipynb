# %%
import pandas as pd

# %%
df = pd.read_table('lineitem.tbl', delimiter='|')

# %%
df.tail(5)
# Out:
#          l_orderkey  l_partkey  l_suppkey  l_linenumber  l_quantity  \
# 5999998     5998726     173489       6007             3          41
# 5999999     5998726      18817       8818             4          40
# 6000000     5998726      41861       4366             5          44
# 6000001     5998726     148889       8890             6          34
# 6000002     5998726     162891       7924             7           7
#
#          l_extendedprice  l_discount  l_tax l_returnflag l_linestatus  \
# 5999998         64061.68        0.04   0.07            N            O
# 5999999         69432.40        0.08   0.08            N            O
# 6000000         79325.84        0.07   0.02            N            O
# 6000001         65887.92        0.08   0.07            N            O
# 6000002         13677.23        0.03   0.06            N            O
#
#          l_shipdate l_commitdate l_receiptdate     l_shipinstruct l_shipmode  \
# ...

# %%
df.columns
# Out:
# Index(['l_orderkey', 'l_partkey', 'l_suppkey', 'l_linenumber', 'l_quantity',
#        'l_extendedprice', 'l_discount', 'l_tax', 'l_returnflag',
#        'l_linestatus', 'l_shipdate', 'l_commitdate', 'l_receiptdate',
#        'l_shipinstruct', 'l_shipmode', 'l_comment', 'Unnamed: 16'],
#       dtype='object')

# %%
df.dtypes
# Out:
# l_orderkey           int64
# l_partkey            int64
# l_suppkey            int64
# l_linenumber         int64
# l_quantity           int64
# l_extendedprice    float64
# l_discount         float64
# l_tax              float64
# l_returnflag        object
# l_linestatus        object
# l_shipdate          object
# l_commitdate        object
# l_receiptdate       object
# l_shipinstruct      object
# l_shipmode          object
# l_comment           object
# Unnamed: 16        float64
# dtype: object

# %%
df.describe()
# Out:
#          l_orderkey     l_partkey     l_suppkey  l_linenumber    l_quantity  \
# count  6.000003e+06  6.000003e+06  6.000003e+06  6.000003e+06  6.000003e+06
# mean   2.999674e+06  1.481994e+05  4.107688e+03  3.000589e+00  1.806942e+01
# std    1.731838e+06  2.491028e+04  2.831859e+03  1.732436e+00  4.646845e+00
# min    1.000000e+00  4.500000e+02  3.500000e+01  1.000000e+00  1.000000e+00
# 25%    1.500422e+06  1.551900e+05  2.736000e+03  2.000000e+00  1.700000e+01
# 50%    3.000324e+06  1.551900e+05  5.191000e+03  3.000000e+00  1.700000e+01
# 75%    4.499456e+06  1.551900e+05  7.695000e+03  4.000000e+00  1.700000e+01
# max    5.998726e+06  1.989340e+05  9.983000e+03  7.000000e+00  5.000000e+01
#
#        l_extendedprice    l_discount         l_tax  Unnamed: 16
# count     6.000003e+06  6.000003e+06  6.000003e+06          0.0
# mean      2.258265e+04  4.384513e-02  2.251806e-02          NaN
# std       5.971354e+03  1.367668e-02  9.710628e-03          NaN
# ...

# %%
df.describe(include='object')
# Out:
#        l_returnflag l_linestatus  l_shipdate l_commitdate l_receiptdate  \
# count       6000003      6000003     6000003      6000003       6000003
# unique            3            2          96           79            97
# top               N            O  1996-03-13   1996-02-12    1996-03-22
# freq        5917556      5917556     5543599      5543599       5543599
#
#        l_shipinstruct l_shipmode                   l_comment
# count         6000003    6000003                     6000003
# unique              4          7                     6000003
# top              NONE        AIR  B3hnOy6xLnMz2jk637jARMR434
# freq          1500549     858890                           1

# %%
orderkey = df.copy()
orderkey.set_index('l_orderkey', inplace=True)

# %%
orderkey.head(15)
# Out:
#             l_partkey  l_suppkey  l_linenumber  l_quantity  l_extendedprice  \
# l_orderkey
# 1              155190       7706             1          17         21168.23
# 1              155190       7706             2          17         21168.23
# 1              155190       7706             3          17         21168.23
# 1              155190       5191             4          17         21168.23
# 1              155190       5191             5          17         21168.23
# 1              155190       7706             6          17         21168.23
# 2              155190       2736             1          17         21168.23
# 3              155190        221             1          17         21168.23
# 3              155190       5191             2          17         21168.23
# 3              155190        221             3          17         21168.23
# 3              155190       7706             4          17         21168.23
# ...

# %%
dropped_version = orderkey.drop('Unnamed: 16', axis=1)

# %%
dropped_version.head()
# Out:
#             l_partkey  l_suppkey  l_linenumber  l_quantity  l_extendedprice  \
# l_orderkey
# 1              155190       7706             1          17         21168.23
# 1              155190       7706             2          17         21168.23
# 1              155190       7706             3          17         21168.23
# 1              155190       5191             4          17         21168.23
# 1              155190       5191             5          17         21168.23
#
#             l_discount  l_tax l_returnflag l_linestatus  l_shipdate  \
# l_orderkey
# 1                 0.04   0.02            N            O  1996-03-13
# 1                 0.04   0.02            N            O  1996-03-13
# 1                 0.04   0.02            N            O  1996-03-13
# 1                 0.04   0.02            N            O  1996-03-13
# 1                 0.04   0.02            N            O  1996-03-13
#
#            l_commitdate l_receiptdate     l_shipinstruct l_shipmode  \
# ...

# %%
dropped_version['l_discount'] = dropped_version['l_discount'] * 100

# %%
dropped_version.head()
# Out:
#             l_partkey  l_suppkey  l_linenumber  l_quantity  l_extendedprice  \
# l_orderkey
# 1              155190       7706             1          17         21168.23
# 1              155190       7706             2          17         21168.23
# 1              155190       7706             3          17         21168.23
# 1              155190       5191             4          17         21168.23
# 1              155190       5191             5          17         21168.23
#
#             l_discount  l_tax l_returnflag l_linestatus  l_shipdate  \
# l_orderkey
# 1                  4.0   0.02            N            O  1996-03-13
# 1                  4.0   0.02            N            O  1996-03-13
# 1                  4.0   0.02            N            O  1996-03-13
# 1                  4.0   0.02            N            O  1996-03-13
# 1                  4.0   0.02            N            O  1996-03-13
#
#            l_commitdate l_receiptdate     l_shipinstruct l_shipmode  \
# ...

# %%
dropped_version['l_tax'] = dropped_version['l_tax'] * 100

# %%
dropped_version.head()
# Out:
#             l_partkey  l_suppkey  l_linenumber  l_quantity  l_extendedprice  \
# l_orderkey
# 1              155190       7706             1          17         21168.23
# 1              155190       7706             2          17         21168.23
# 1              155190       7706             3          17         21168.23
# 1              155190       5191             4          17         21168.23
# 1              155190       5191             5          17         21168.23
#
#             l_discount  l_tax l_returnflag l_linestatus  l_shipdate  \
# l_orderkey
# 1                  4.0    2.0            N            O  1996-03-13
# 1                  4.0    2.0            N            O  1996-03-13
# 1                  4.0    2.0            N            O  1996-03-13
# 1                  4.0    2.0            N            O  1996-03-13
# 1                  4.0    2.0            N            O  1996-03-13
#
#            l_commitdate l_receiptdate     l_shipinstruct l_shipmode  \
# ...

# %%
dropped_version.dtypes
# Out:
# l_partkey            int64
# l_suppkey            int64
# l_linenumber         int64
# l_quantity           int64
# l_extendedprice    float64
# l_discount         float64
# l_tax              float64
# l_returnflag        object
# l_linestatus        object
# l_shipdate          object
# l_commitdate        object
# l_receiptdate       object
# l_shipinstruct      object
# l_shipmode          object
# l_comment           object
# dtype: object

# %%
dropped_version['l_extendedprice'] = dropped_version['l_extendedprice'].round().astype(int)

# %%
dropped_version.head()
# Out:
#             l_partkey  l_suppkey  l_linenumber  l_quantity  l_extendedprice  \
# l_orderkey
# 1              155190       7706             1          17            21168
# 1              155190       7706             2          17            21168
# 1              155190       7706             3          17            21168
# 1              155190       5191             4          17            21168
# 1              155190       5191             5          17            21168
#
#             l_discount  l_tax l_returnflag l_linestatus  l_shipdate  \
# l_orderkey
# 1                  4.0    2.0            N            O  1996-03-13
# 1                  4.0    2.0            N            O  1996-03-13
# 1                  4.0    2.0            N            O  1996-03-13
# 1                  4.0    2.0            N            O  1996-03-13
# 1                  4.0    2.0            N            O  1996-03-13
#
#            l_commitdate l_receiptdate     l_shipinstruct l_shipmode  \
# ...

# %%
dropped_version['l_discount'] = dropped_version['l_discount'].astype(int)

# %%
dropped_version['l_tax'] = dropped_version['l_tax'].astype(int)

# %%
dropped_version.dtypes
# Out:
# l_partkey           int64
# l_suppkey           int64
# l_linenumber        int64
# l_quantity          int64
# l_extendedprice     int64
# l_discount          int64
# l_tax               int64
# l_returnflag       object
# l_linestatus       object
# l_shipdate         object
# l_commitdate       object
# l_receiptdate      object
# l_shipinstruct     object
# l_shipmode         object
# l_comment          object
# dtype: object

# %%
dropped_version.head()
# Out:
#             l_partkey  l_suppkey  l_linenumber  l_quantity  l_extendedprice  \
# l_orderkey
# 1              155190       7706             1          17            21168
# 1              155190       7706             2          17            21168
# 1              155190       7706             3          17            21168
# 1              155190       5191             4          17            21168
# 1              155190       5191             5          17            21168
#
#             l_discount  l_tax l_returnflag l_linestatus  l_shipdate  \
# l_orderkey
# 1                    4      2            N            O  1996-03-13
# 1                    4      2            N            O  1996-03-13
# 1                    4      2            N            O  1996-03-13
# 1                    4      2            N            O  1996-03-13
# 1                    4      2            N            O  1996-03-13
#
#            l_commitdate l_receiptdate     l_shipinstruct l_shipmode  \
# ...

# %%
dropped_version.to_csv('skwed.csv')
